# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/shipping_data.csv')
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
print(df.shape)
# Out:
# (10999, 12)

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df.describe()
df['Mode_of_Shipment'].value_counts()
# Out:
# Mode_of_Shipment
# Ship      7462
# Flight    1777
# Road      1760
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.boxplot(x=df['Cost_of_the_Product'])
# Out:
# <Axes: xlabel='Cost_of_the_Product'>

# %%
df['Cost_of_the_Product'].hist(bins=30)
# Out:
# <Axes: >

# %%
df['Mode_of_Shipment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Mode_of_Shipment'>

# %%
sns.boxplot(y='Mode_of_Shipment', x='Cost_of_the_Product', data=df)
# Out:
# <Axes: xlabel='Cost_of_the_Product', ylabel='Mode_of_Shipment'>

# %%
sns.countplot(x='Reached.on.Time_Y.N', data=df)
# Out:
# <Axes: xlabel='Reached.on.Time_Y.N', ylabel='count'>

# %%
sns.pairplot(df[['Cost_of_the_Product', 'Discount_offered', 'Weight_in_gms', 'Reached.on.Time_Y.N']])

# %%
df.groupby('Mode_of_Shipment')['Cost_of_the_Product'].mean()
# Out:
# Mode_of_Shipment
# Flight    209.306697
# Road      210.475568
# Ship      210.343072
# Name: Cost_of_the_Product, dtype: float64
